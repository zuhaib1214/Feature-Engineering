# %%
import pandas as pd
import numpy as np
import sklearn as sk
import seaborn as sns

# %%
df=pd.read_csv('coin_Bitcoin.csv')
df
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
from pandas_profiling import ProfileReport
ProfileReport()
profile = ProfileReport(df, title="Profiling Report")
profile.to_file("your_report.html")
# Out:
# C:\Users\zuhai\AppData\Local\Temp\ipykernel_2424\1144690724.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.dtypes
# Out:
# SNo            int64
# Name          object
# Symbol        object
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Marketcap    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
df=df.drop(columns=['SNo','Name','Symbol'],axis=1)
df
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['High']=df['High'].astype(int)
df['Low']=df['Low'].astype(int)
df['Open']=df['Open'].astype(int)
df['Close']=df['Close'].astype(int)
df['Volume']=df['Volume'].astype(int)
df['Marketcap']=df['Marketcap'].astype(int)

# %%
df
# Out:
#                      Date   High    Low   Open  Close      Volume   Marketcap
# 0     2013-04-29 23:59:59    147    134    134    144           0  1603768864
# 1     2013-04-30 23:59:59    146    134    144    139           0  1542813125
# 2     2013-05-01 23:59:59    139    107    139    116           0  1298954593
# 3     2013-05-02 23:59:59    125     92    116    105           0  1168517495
# 4     2013-05-03 23:59:59    108     79    106     97           0  1085995168
# ...                   ...    ...    ...    ...    ...         ...         ...
# 2986  2021-07-02 23:59:59  33939  32770  33549  33897 -2147483648 -2147483648
# 2987  2021-07-03 23:59:59  34909  33402  33854  34668 -2147483648 -2147483648
# 2988  2021-07-04 23:59:59  35937  34396  34665  35287 -2147483648 -2147483648
# 2989  2021-07-05 23:59:59  35284  33213  35284  33746 -2147483648 -2147483648
# 2990  2021-07-06 23:59:59  35038  33599  33723  34235 -2147483648 -2147483648
#
# [2991 rows x 7 columns]

# %%
import datetime as dt
df["Date"]=pd.to_datetime(df["Date"])
df['Date'] = df["Date"].dt.year
df
# Out:
#       Date   High    Low   Open  Close      Volume   Marketcap
# 0     2013    147    134    134    144           0  1603768864
# 1     2013    146    134    144    139           0  1542813125
# 2     2013    139    107    139    116           0  1298954593
# 3     2013    125     92    116    105           0  1168517495
# 4     2013    108     79    106     97           0  1085995168
# ...    ...    ...    ...    ...    ...         ...         ...
# 2986  2021  33939  32770  33549  33897 -2147483648 -2147483648
# 2987  2021  34909  33402  33854  34668 -2147483648 -2147483648
# 2988  2021  35937  34396  34665  35287 -2147483648 -2147483648
# 2989  2021  35284  33213  35284  33746 -2147483648 -2147483648
# 2990  2021  35038  33599  33723  34235 -2147483648 -2147483648
#
# [2991 rows x 7 columns]

# %%
line = sns.distplot(df['Open'])
# Out:
# C:\Users\zuhai\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('Marketcap',axis=1),df['Marketcap'],test_size=0.2,random_state=0)

# %%
x_test
# Out:
#       Date  High   Low  Open  Close      Volume
# 936   2015   328   319   322    326    28200500
# 1311  2016   747   736   736    745    84070800
# 1023  2016   408   401   401    407    73093104
# 1548  2017  2768  2480  2757   2576  1460089984
# 1386  2017  1002   976   998    990   100607000
# ...    ...   ...   ...   ...    ...         ...
# 1122  2016   450   446   446    449    65231000
# 476   2014   499   443   491    461    50783800
# 1368  2017   919   902   902    917   131958000
# 841   2015   257   211   257    211    42147200
# 1313  2016   781   757   757    777   127605000
#
# [599 rows x 6 columns]

# %%
x_train
# Out:
#       Date   High    Low   Open  Close      Volume
# 728   2015    233    218    219    229    38574000
# 271   2014    861    792    796    853    24303900
# 1074  2016    423    420    423    422    57858600
# 369   2014    449    430    449    437     9849640
# 2461  2020   8514   8266   8405   8445 -2147483648
# ...    ...    ...    ...    ...    ...         ...
# 763   2015    231    221    230    222    26090500
# 835   2015    270    265    270    266    26815400
# 1653  2017   7253   7023   7023   7144 -2147483648
# 2607  2020   9482   9328   9481   9411 -2147483648
# 2732  2020  13184  11900  11913  12823 -2147483648
#
# [2392 rows x 6 columns]

# %%
y_test
# Out:
# 936    -2147483648
# 1311   -2147483648
# 1023   -2147483648
# 1548   -2147483648
# 1386   -2147483648
#            ...
# 1122   -2147483648
# 476    -2147483648
# 1368   -2147483648
# 841    -2147483648
# 1313   -2147483648
# Name: Marketcap, Length: 599, dtype: int32

# %%
x_train_sample = x_train
x_test_sample = x_test

# %%
y_train
# Out:
# 728    -2147483648
# 271    -2147483648
# 1074   -2147483648
# 369    -2147483648
# 2461   -2147483648
#            ...
# 763    -2147483648
# 835    -2147483648
# 1653   -2147483648
# 2607   -2147483648
# 2732   -2147483648
# Name: Marketcap, Length: 2392, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
stan=StandardScaler()
x_train_ss=stan.fit_transform(x_train)
x_test_ss=stan.transform(x_test)

# %%
x_train_ss
# Out:
# array([[-0.82029632, -0.57940852, -0.58396908, -0.58188462, -0.58064635,
#          0.79048387],
#        [-1.2383975 , -0.52447389, -0.53023197, -0.52976554, -0.52449293,
#          0.77863025],
#        [-0.40219515, -0.56278817, -0.56505811, -0.56345777, -0.56327838,
#          0.80650283],
#        ...,
#        [ 0.01590602,  0.03466964,  0.05310593,  0.03270505,  0.04163073,
#         -1.02538885],
#        [ 1.27020954,  0.22965257,  0.26889695,  0.25473053,  0.24563683,
#         -1.02538885],
#        [ 1.27020954,  0.55348694,  0.50968416,  0.4744075 ,  0.55268085,
#         -1.02538885]])

# %%
y_train
# Out:
# 728    -2147483648
# 271    -2147483648
# 1074   -2147483648
# 369    -2147483648
# 2461   -2147483648
#            ...
# 763    -2147483648
# 835    -2147483648
# 1653   -2147483648
# 2607   -2147483648
# 2732   -2147483648
# Name: Marketcap, Length: 2392, dtype: int32

# %%
x_train_ss=pd.DataFrame(x_train_ss).rename(columns={0:'Date',1:'High',2:'Low',3:'Open',4:'Close',5:'volume'})
x_train_ss
# Out:
#           Date      High       Low      Open     Close    volume
# 0    -0.820296 -0.579409 -0.583969 -0.581885 -0.580646  0.790484
# 1    -1.238397 -0.524474 -0.530232 -0.529766 -0.524493  0.778630
# 2    -0.402195 -0.562788 -0.565058 -0.563458 -0.563278  0.806503
# 3    -1.238397 -0.560514 -0.564122 -0.561109 -0.561929  0.766624
# 4     1.270210  0.144976  0.169474  0.157538  0.158707 -1.025389
# ...        ...       ...       ...       ...       ...       ...
# 2387 -0.820296 -0.579583 -0.583688 -0.580891 -0.581276  0.780114
# 2388 -0.820296 -0.576172 -0.579569 -0.577278 -0.577317  0.780716
# 2389  0.015906  0.034670  0.053106  0.032705  0.041631 -1.025389
# 2390  1.270210  0.229653  0.268897  0.254731  0.245637 -1.025389
# 2391  1.270210  0.553487  0.509684  0.474407  0.552681 -1.025389
#
# [2392 rows x 6 columns]

# %%
x_test_ss=pd.DataFrame(x_test_ss).rename(columns={0:'Date',1:'High',2:'Low',3:'Open',4:'Close',5:'volume'})

# %%
x_test_ss
# Out:
#          Date      High       Low      Open     Close    volume
# 0   -0.820296 -0.571098 -0.574514 -0.572581 -0.571917  0.781867
# 1   -0.402195 -0.534446 -0.535475 -0.535185 -0.534212  0.828276
# 2   -0.402195 -0.564100 -0.566837 -0.565445 -0.564628  0.819158
# 3    0.015906 -0.357658 -0.372204 -0.352633 -0.369441  1.971282
# 4    0.015906 -0.512140 -0.513006 -0.511519 -0.512164  0.842012
# ..        ...       ...       ...       ...       ...       ...
# 594 -0.402195 -0.560426 -0.562624 -0.561380 -0.560849  0.812627
# 595 -1.238397 -0.556140 -0.562905 -0.557315 -0.559769  0.800626
# 596  0.015906 -0.519400 -0.519934 -0.520191 -0.518734  0.868054
# 597 -0.820296 -0.577309 -0.584624 -0.578452 -0.582266  0.793452
# 598 -0.402195 -0.531472 -0.533509 -0.533288 -0.531332  0.864438
#
# [599 rows x 6 columns]

# %%
line=sns.displot(df['Open'])

# %%
line=sns.displot(df['Low'])

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer()

# %%
x_train_ss_trans=pt.fit_transform(x_train_ss)
x_test_ss_trans=pt.transform(x_test_ss)

# %%
x_train_ss_trans
# Out:
# array([[-0.82411894, -1.03032001, -1.03312018, -1.03397842, -1.03038481,
#          0.80465496],
#        [-1.23130558, -0.8024546 , -0.81329512, -0.81858515, -0.79882548,
#          0.79343477],
#        [-0.41335697, -0.95967773, -0.95405556, -0.95618741, -0.95698395,
#          0.81980639],
#        ...,
#        [ 0.00212367,  0.71616052,  0.73463926,  0.70847657,  0.72367873,
#         -1.0306907 ],
#        [ 1.27918004,  0.98069731,  1.01233711,  1.00373089,  0.99473206,
#         -1.0306907 ],
#        [ 1.27918004,  1.27357124,  1.22976832,  1.20894676,  1.26915743,
#         -1.0306907 ]])

# %%
x_train_ss_trans=pd.DataFrame(x_train_ss_trans).rename(columns={0:'Date',1:'High',2:'Low',3:'Open',4:'Close',5:'volume'})

# %%
x_test_ss_trans=pd.DataFrame(x_test_ss_trans).rename(columns={0:'Date',1:'High',2:'Low',3:'Open',4:'Close',5:'volume'})

# %%
x_train_ss_trans
# Out:
#           Date      High       Low      Open     Close    volume
# 0    -0.824119 -1.030320 -1.033120 -1.033978 -1.030385  0.804655
# 1    -1.231306 -0.802455 -0.813295 -0.818585 -0.798825  0.793435
# 2    -0.413357 -0.959678 -0.954056 -0.956187 -0.956984  0.819806
# 3    -1.231306 -0.950127 -0.950190 -0.946402 -0.951347  0.782062
# 4     1.279180  0.876860  0.896916  0.888308  0.890824 -1.030691
# ...        ...       ...       ...       ...       ...       ...
# 2387 -0.824119 -1.031072 -1.031932 -1.029738 -1.033077  0.794840
# 2388 -0.824119 -1.016446 -1.014557 -1.014361 -1.016188  0.795410
# 2389  0.002124  0.716161  0.734639  0.708477  0.723679 -1.030691
# 2390  1.279180  0.980697  1.012337  1.003731  0.994732 -1.030691
# 2391  1.279180  1.273571  1.229768  1.208947  1.269157 -1.030691
#
# [2392 rows x 6 columns]

# %%
x_test_ss_trans
# Out:
#          Date      High       Low      Open     Close    volume
# 0   -0.824119 -0.994812 -0.993354 -0.994476 -0.993293  0.796499
# 1   -0.413357 -0.842627 -0.834087 -0.840319 -0.837717  0.840380
# 2   -0.413357 -0.965201 -0.961413 -0.964490 -0.962631  0.831766
# 3    0.002124 -0.205060 -0.249999 -0.188936 -0.242463  1.892495
# 4    0.002124 -0.753487 -0.745958 -0.746529 -0.750194  0.853346
# ..        ...       ...       ...       ...       ...       ...
# 594 -0.413357 -0.949760 -0.944014 -0.947530 -0.946844  0.825595
# 595 -1.231306 -0.931837 -0.945171 -0.930658 -0.942347  0.814249
# 596  0.002124 -0.782216 -0.772859 -0.780560 -0.776010  0.877903
# 597 -0.824119 -1.021314 -1.035894 -1.019351 -1.037313  0.807463
# 598 -0.413357 -0.830591 -0.826274 -0.832695 -0.826143  0.874496
#
# [599 rows x 6 columns]

# %%
from scipy import stats
import matplotlib.pyplot as plt

# %%
for col in x_train_ss:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(x_train_ss[col])

    plt.subplot(122)
    stats.probplot(x_train_ss[col],dist="norm",plot=plt)
    plt.title(col)

    plt.show()
# Out:
# C:\Users\zuhai\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\zuhai\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ms=MinMaxScaler()
x_train=ms.fit_transform(x_train)
x_test=ms.transform(x_test)

x_train=pd.DataFrame(x_train).rename(columns={0:'Date',1:'High',2:'Low',3:'Open',4:'Close',5:'volume'})

x_test=pd.DataFrame(x_test).rename(columns={0:'Date',1:'High',2:'Low',3:'Open',4:'Close',5:'volume'})

# %%
for col in x_train:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(x_train[col])

    plt.subplot(122)
    stats.probplot(x_train[col],dist="norm",plot=plt)
    plt.title(col)

    plt.show()
# Out:
# C:\Users\zuhai\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\zuhai\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
trf= FunctionTransformer(func=np.log1p)

# %%
x_train_sample=trf.fit_transform(x_train_sample)
x_test_sample=trf.transform(x_test_sample)


x_train_sample=pd.DataFrame(x_train_sample).rename(columns={0:'Date',1:'High',2:'Low',3:'Open',4:'Close',5:'volume'})

x_test_sample=pd.DataFrame(x_test_sample).rename(columns={0:'Date',1:'High',2:'Low',3:'Open',4:'Close',5:'volume'})
# Out:
# C:\Users\zuhai\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)

# %%
x_train_sample
# Out:
#           Date      High       Low      Open     Close     Volume
# 728   7.608871  5.455321  5.389072  5.393628  5.438079  17.468089
# 271   7.608374  6.759255  6.675823  6.680855  6.749931  17.006147
# 1074  7.609367  6.049733  6.042633  6.049733  6.047372  17.873513
# 369   7.608374  6.109248  6.066108  6.109248  6.082219  16.102946
# 2461  7.611348  9.049585  9.020027  9.036701  9.041448        NaN
# ...        ...       ...       ...       ...       ...        ...
# 763   7.608871  5.446737  5.402677  5.442418  5.407172  17.077082
# 835   7.608871  5.602119  5.583496  5.602119  5.587249  17.104487
# 1653  7.609862  8.889308  8.857088  8.857088  8.874168        NaN
# 2607  7.611348  9.157256  9.140883  9.157151  9.149741        NaN
# 2732  7.611348  9.486835  9.384378  9.385469  9.459074        NaN
#
# [2392 rows x 6 columns]

# %%
for col in x_train_sample:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(x_train_sample[col])

    plt.subplot(122)
    stats.probplot(x_train_sample[col],dist="norm",plot=plt)
    plt.title(col)

    plt.show()
# Out:
# C:\Users\zuhai\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\zuhai\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Out:
# C:\Users\zuhai\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\zuhai\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
x_train_sample.drop(columns=['Date','Volume'],inplace=True)
x_test_sample.drop(columns=['Date','Volume'],inplace=True)

# %%
y_train.isnull().sum()
# Out:
# 0

# %%
lr=LinearRegression()

# %%
model=lr.fit(x_train_sample,y_train)

# %%
y_pred=model.predict(x_test_sample)
r2_score(y_test,y_pred)*100
# Out:
# 11.20074649423759
